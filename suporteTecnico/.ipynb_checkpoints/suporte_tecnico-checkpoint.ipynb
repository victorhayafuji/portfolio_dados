# %% [markdown]
# # Transformando o Atendimento ao Cliente: Um Diagnóstico Baseado em Dados

# %% [markdown]
# ## O Desafio: Melhorando a Experiência do Cliente

# %% [markdown]
# João, um cliente fiel há mais de cinco anos, tentou entrar em contato com o suporte técnico após enfrentar um problema com seu serviço. Depois de esperar 40 minutos na linha e ser transferido três vezes, ele desistiu e expressou sua frustração nas redes sociais. E João não era o único.
#
# A insatisfação com o atendimento ao cliente se tornou um problema crítico para a empresa. Nos últimos três meses, a taxa de cancelamento aumentou em 15%, e as avaliações negativas cresceram 30%. Comentários frequentes mencionavam lentidão no atendimento, dificuldade na resolução de problemas e falta de comunicação eficiente.
#
# Diante desse cenário, a empresa contratou uma consultoria especializada em análise de dados para entender quais são os principais desafios enfrentados no suporte técnico e como transformá-lo em uma vantagem competitiva.
#
# Este estudo tem como objetivo analisar o desempenho do suporte técnico, identificando padrões e fatores que impactam a eficiência do atendimento e a satisfação do cliente. Nossa análise se baseia em dados detalhados do suporte, e buscamos responder a questões-chave:
#
# ### Perguntas-Chave da Análise
#
# Para compreender melhor os desafios e oportunidades no suporte técnico, definimos as seguintes questões-chave que guiarão nossa investigação:
#
# - Quais são os maiores gargalos no atendimento ao cliente? Identificar os pontos que mais contribuem para a insatisfação dos clientes, como tempo de espera, transferências excessivas ou baixa resolutividade.
#
# - O tempo de resposta está impactando a satisfação dos clientes? Analisar se há correlação entre tempos de espera prolongados e aumento nas reclamações ou cancelamentos.
#
# - Quais soluções podem ser implementadas para otimizar o suporte? Explorar abordagens como automação, requalificação da equipe ou adoção de novas tecnologias para melhorar a experiência do cliente.
#
# - Existe uma diferença na satisfação entre diferentes canais de atendimento? Comparar o desempenho de suporte via telefone, chat e e-mail para entender quais oferecem melhor experiência ao usuário.
#
# - Como a experiência do cliente no suporte afeta a fidelização? Investigar se clientes com experiências negativas no suporte tendem a cancelar ou migrar para concorrentes.
#
# Com uma abordagem orientada a dados, pretendemos não apenas diagnosticar os problemas, mas também oferecer soluções concretas que impactem positivamente a experiência do cliente.
#
# Vamos mergulhar nos insights e descobrir como transformar desafios em oportunidades!

# %% [markdown]
# ## Carregamento dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.__version__
# Out:
# '1.2.5'

# %%
# Definir o número de casas decimais desejado

pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# Lendo os dados da planilha Excel

df = pd.read_excel('Exercicio_suporte_tecnico.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025 entries, 0 to 3024
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ticket_id                      3025 non-null   int64
#  1   inicio_atendimento             3025 non-null   datetime64[ns]
#  2   fim_atendimento                3025 non-null   datetime64[ns]
#  3   turno                          3025 non-null   object
#  4   atendente_nome                 3025 non-null   object
#  5   resolvido_na_primeira_chamada  3025 non-null   object
#  6   conversao_atendimento          3025 non-null   object
#  7   nota_csat                      3006 non-null   float64
#  8   produto                        3025 non-null   object
#  9   cliente                        3025 non-null   object
#  10  ticket_reaberto                3025 non-null   object
#  11  ticket_original                939 non-null    float64
# ...

# %%
df.head()
# Out:
#    ticket_id  inicio_atendimento     fim_atendimento  turno   atendente_nome  \
# 0       1048 2023-12-01 06:00:00 2023-12-01 06:15:00  Manhã      Carla Souza
# 1        436 2023-12-01 06:12:00 2023-12-01 06:18:00  Manhã        Ana Paula
# 2       1725 2023-12-01 06:18:00 2023-12-01 06:52:00  Manhã  Maria Fernandes
# 3       1186 2023-12-01 06:19:00 2023-12-01 06:56:00  Manhã      Carla Souza
# 4       2683 2023-12-01 06:27:00 2023-12-01 06:50:00  Manhã  Ricardo Andrade
#
#   resolvido_na_primeira_chamada conversao_atendimento  nota_csat    produto  \
# 0                           Sim                   Sim       7.00  Serviço C
# 1                           Sim                   Sim       4.00  Serviço C
# 2                           Não                   Não       3.00  Produto B
# 3                           Sim                   Sim       4.00  Serviço C
# 4                           Não                   Não       2.00  Produto A
#
#      cliente ticket_reaberto  ticket_original
# ...

# %% [markdown]
# ## Exploração dos Dados

# %% [markdown]
# **Os dados utilizados para esta análise foram extraídos do sistema de suporte técnico e incluem informações detalhadas sobre:**
#
# - **Tempo de Atendimento (TMA):** Duração entre o início e o fim do atendimento.
#
# - **Satisfação do Cliente (CSAT):** Nota atribuída pelos clientes após o atendimento.
#
# - **Conversão do Atendimento:** Indica se o atendimento resultou em uma conversão bem-sucedida.
#
# - **Reabertura de Tickets:** Se o cliente precisou de um novo atendimento para o mesmo problema.
#
# - **Turno e Atendente:** Identifica o horário e o profissional que realizou o atendimento.
#
# - **Produto/Serviço:** Categoria associada ao ticket de suporte.
#
# Para garantir a qualidade da análise, foram realizados processos de tratamento de dados, incluindo a remoção de inconsistências e a padronização dos formatos de informação.
#
# Também segmentamos os dados para entender padrões específicos em diferentes cenários, como por produto, atendente e horário de atendimento.

# %% [markdown]
# ## Análise Univariada

# %% [markdown]
# ### a) O Tempo Médio de Atendimento (TMA) e os Quartis
#
# Uma das principais preocupações da empresa era entender quanto tempo seus clientes esperavam por uma solução. Para isso, utilizamos o conceito de quartis, buscando responder à seguinte questão:
#
# **Qual é o tempo de atendimento que separa os 25% dos tickets mais rápidos?**

# %%
# Criando uma coluna para o cálculo do TMA

df['TMA'] =  (df['fim_atendimento'] - df['inicio_atendimento']).dt.total_seconds()/60

# %%
# Estatística descritica básica - Medidas Resumo

df['TMA'].describe()
# Out:
# count   3025.00
# mean      33.30
# std       17.26
# min        2.00
# 25%       18.00
# 50%       36.00
# 75%       48.00
# max       60.00
# Name: TMA, dtype: float64

# %%
# Configuração do gráfico
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['TMA'], color='lightblue')

# Personalização do gráfico
plt.title('Boxplot do Tempo Médio de Atendimento (TMA)')
plt.xlabel('TMA (minutos)')

# Exibir o gráfico
plt.show()

# %% [markdown]
# Os dados revelaram que 25% dos atendimentos mais rápidos são resolvidos abaixo de **18 minutos**.
#
# Nenhum outlier significativo foi identificado, indicando que os tempos de atendimento estão distribuídos de forma uniforme. Isso sugere um padrão relativamente homogêneo de atendimento, sem grandes variações extremas.

# %% [markdown]
# ### b) Tickets por turno de trabalho
#
# Outra questão relevante foi identificar se há concentração de chamados em algum período do dia. Ao analisar os dados, a consultoria descobriu que:

# %%
# Frequencia de tickets por turno de trabalho

tabela_frequencia_turno = df['turno'].value_counts().reset_index()
tabela_frequencia_turno.columns = ['Turno', 'Frequencia Absoluta']

tabela_frequencia_turno['Frequencia Relativa'] = (
    100 * (tabela_frequencia_turno['Frequencia Absoluta'] / tabela_frequencia_turno['Frequencia Absoluta'].sum())
).apply('{:.2f}%'.format)

tabela_frequencia_turno['Frequencia Acumulada'] = (
    tabela_frequencia_turno['Frequencia Absoluta'].cumsum() / tabela_frequencia_turno['Frequencia Absoluta'].sum() * 100
).apply('{:.2f}%'.format)

tabela_frequencia_turno
# Out:
#    Turno  Frequencia Absoluta Frequencia Relativa Frequencia Acumulada
# 0  Noite                 1289              42.61%               42.61%
# 1  Manhã                 1022              33.79%               76.40%
# 2  Tarde                  714              23.60%              100.00%

# %% [markdown]
# 42,6% dos chamados estão concentrados no turno da noite, o que corresponde a quase o dobro dos atendimentos durante o período da Tarde.
#
# Isso pode significar dois problemas:
#
# **1. Uma sobrecarga de atendentes nesse período, causando aumento no tempo médio de atendimento.**
#
# **2. Uma possível ineficiência na distribuição da equipe, com períodos de baixa demanda em que recursos estão subutilizados.**
#
# Essas informações permitiram uma reavaliação da escala de trabalho, equilibrando melhor a distribuição dos atendentes ao longo do dia.

# %% [markdown]
# ### c) Frequência de Intervalos para TMA
# Para uma análise mais aprofundada, os tempos de atendimento foram classificados em três categorias:
# - Baixo (2:00 a 18:00 minutos) – Atendimento rápido e eficiente.
# - Médio (18:00 a 36:00 minutos) – Atendimento dentro da média, mas com espaço para otimização.
# - Alto (36:00 a 48:00 minutos) ou Muito Alto (48:00 a 60:00 minutos) – Atendimentos demorados que podem gerar insatisfação.

# %%
# Calculando os quartis

q1 = df['TMA'].quantile(0.25)
q2 = df['TMA'].quantile(0.50)
q3 = df['TMA'].quantile(0.75)

# Criando os intervalos de classificação baseados nos quartis

df['Classificação'] = pd.cut(
    df['TMA'], bins=[df['TMA'].min(), q1, q2, q3, df['TMA'].max()], 
    labels=['Baixo', 'Médio', 'Alto', 'Muito Alto'], 
    include_lowest=True
)

# Criando a tabela de frequência dos intervalos de classificação e incluindo os valores dos quartis

tabela_classificacao_TMA = df['Classificação'].value_counts().reset_index()
tabela_classificacao_TMA.columns = ['Classificação', 'Frequência Absoluta']
tabela_classificacao_TMA['Frequência Relativa'] = (
    100 * tabela_classificacao_TMA['Frequência Absoluta'] / tabela_classificacao_TMA['Frequência Absoluta'].sum()
).apply('{:.2f}%'.format)

# Adicionando os valores dos quartis correspondentes

quartis_df = pd.DataFrame({
    'Classificação': ['Baixo', 'Médio', 'Alto', 'Muito Alto'], 
    'Limite Inferior': [df['TMA'].min(), q1, q2, q3],
    'Limite Superior': [q1, q2, q3, df['TMA'].max()]
})

# Mesclando a tabela existente com os valores dos quartis

tabela_classificacao_TMA = tabela_classificacao_TMA.merge(quartis_df, on='Classificação', how='left')

tabela_classificacao_TMA
# Out:
#   Classificação  Frequência Absoluta Frequência Relativa  Limite Inferior  \
# 0         Baixo                  786              25.98%             2.00
# 1         Médio                  755              24.96%            18.00
# 2          Alto                  751              24.83%            36.00
# 3    Muito Alto                  733              24.23%            48.00
#
#    Limite Superior
# 0            18.00
# 1            36.00
# 2            48.00
# 3            60.00

# %% [markdown]
# **Os insights foram claros:**
#
# 49,06% dos chamados pertencem ao grupo "Alto" ou "Muito Alto", o que significa que uma parte relevante dos clientes está enfrentando longos tempos de espera.
#
# Alguns atendentes consistentemente apresentam tempos de atendimento elevados, o que pode indicar necessidade de treinamento adicional ou redistribuição de tarefas.
#
# Isso levou a empresa a repensar seus processos internos, implementando ações para reduzir os tempos médios nos atendimentos mais demorados.

# %% [markdown]
# ### d) Taxa de Conversão de Atendimento
#
# Assim como o Tempo Médio de Atendimento, analisamos a Taxa de Conversão de Atendimento – ou seja, quantos chamados foram resolvidos com sucesso.

# %%
(df['conversao_atendimento'].value_counts()*100/df['conversao_atendimento'].count()).apply('{:.2f}%'.format)
# Out:
# Não    51.21%
# Sim    48.79%
# Name: conversao_atendimento, dtype: object

# %% [markdown]
# **Principais descobertas:**
#
# - Atendentes com menor TMA tendem a apresentar maiores taxas de conversão.
#
# - Já os chamados com tempos elevados têm menor taxa de conversão, sugerindo que clientes que aguardam muito tempo podem perder a paciência e buscar outras soluções.
#
# Esse dado reforçou a necessidade de equilibrar **eficiência e qualidade**, garantindo que um atendimento rápido também seja eficaz.

# %% [markdown]
# ### e) Frequência de Atendimentos por Atendente
#
# Por fim, analisamos a frequência de chamados por atendente para identificar padrões de desempenho.

# %%
# Frequencia absoluta e Relativa

tabela_frequencia_atendente = df['atendente_nome'].value_counts().reset_index()
tabela_frequencia_atendente.columns = ['Atendente', 'Frequência Absoluta']
tabela_frequencia_atendente['Frequência Relativa'] = (
    100 * (tabela_frequencia_atendente['Frequência Absoluta'] / tabela_frequencia_atendente['Frequência Absoluta'].sum())
).apply('{:.2f}%'.format)

tabela_frequencia_atendente
# Out:
#          Atendente  Frequência Absoluta Frequência Relativa
# 0    Lucas Martins                  524              17.32%
# 1        Ana Paula                  512              16.93%
# 2       João Silva                  508              16.79%
# 3  Maria Fernandes                  507              16.76%
# 4      Carla Souza                  501              16.56%
# 5  Ricardo Andrade                  473              15.64%

# %% [markdown]
# Existe um equilibrio entre os atendentes, a não ser por uma pequena maior participação de Lucas (17,32%) e uma menor de Ricardo (15,64%).

# %% [markdown]
# ## Análise Bivariada

# %% [markdown]
# ### a) Correlação entre TMA e nota do atendimento

# %%
df['TMA'].corr(df['nota_csat'], method='pearson')
# Out:
# 0.006503607346734087

# %%
# Visualizando a relação entre as duas variáveis em um gráfico
# Criar o gráfico de dispersão

plt.scatter(df['TMA'], df['nota_csat'])

# Personalizar o gráfico

plt.title('TMA x Nota Atendimento')
plt.xlabel('TMA')
plt.ylabel('Nota Atendimento')

# Mostrar o gráfico

plt.show()

# %% [markdown]
# A relação entre o TMA e a Nota de Atendimento é **quase inexistente**, pois o valor para a correlação linear de Pearson calculado é de 0,0065, ou seja, próxima de zero.
#
# O gráfico de dispersão evidencia essa ausência de relação.

# %% [markdown]
# ### b) Nota do Atendimento se há ou não conversão

# %%
# Criar o boxplot com seaborn

sns.boxplot(x=df['conversao_atendimento'], y=df['nota_csat'], palette='Blues')

# Personalizar o gráfico

plt.title('Conversão do Atendimento x Nota Atendimento')
plt.xlabel('Conversão do Atendimento')
plt.ylabel('Nota Atendimento')

# Mostrar o gráfico

plt.show()

# %% [markdown]
# Com base no gráfico, percebemos que não há indicação de haver diferenças de nota se houve conversão do atendimento.

# %% [markdown]
# ### c) Nota do Atendimento se foi resolvido no primeiro contato

# %%
# Criar o boxplot com seaborn

sns.boxplot(x=df['resolvido_na_primeira_chamada'], y=df['nota_csat'], palette='Blues')

# Personalizar o gráfico

plt.title('Resolução no Primeiro Contato x Nota Atendimento')
plt.xlabel('Resolução no Primeiro Contato')
plt.ylabel('Nota Atendimento')

# Mostrar o gráfico

plt.show()

# %% [markdown]
# Com base no gráfico, percebemos que as notas são bem maiores quando o ticket é resolvido na primeira chamada em relação as que não são.

# %% [markdown]
# ### d) IV para resolução no primeiro contato

# %%
# Tabela de Frequência Relativa

df_iv = pd.crosstab(df['atendente_nome'], df['resolvido_na_primeira_chamada'], margins=True, margins_name='Total', normalize='columns')

df_iv
# Out:
# resolvido_na_primeira_chamada  Não  Sim  Total
# atendente_nome
# Ana Paula                     0.17 0.17   0.17
# Carla Souza                   0.18 0.16   0.17
# João Silva                    0.17 0.17   0.17
# Lucas Martins                 0.15 0.18   0.17
# Maria Fernandes               0.19 0.16   0.17
# Ricardo Andrade               0.15 0.16   0.16

# %%
# Cálculo do IV

df_iv['LN(Odds)'] = np.log(df_iv['Não']/df_iv['Sim'])
df_iv['IV'] = (df_iv['Não'] - df_iv['Sim'])*df_iv['LN(Odds)']
df_iv['IV'].sum().round(3)
# Out:
# 0.015

# %% [markdown]
# O IV encontrado para a variável atendente é de 0,015, o que indica que o poder de discriminação é fraco para explicar a resolução no primeiro contato.

# %% [markdown]
# ### e) Segmentação de Atendimento por Tipo de Produto

# %% [markdown]
# Vamos analisar se há diferenças no Tempo Médio de Atendimento (TMA) e na Satisfação do Cliente (CSAT) entre os diferentes produtos/serviços.

# %%
# Estatísticas descritivas do TMA e Nota CSAT por Produto
tma_por_produto = df.groupby("produto")["TMA"].describe()
csat_por_produto = df.groupby("produto")["nota_csat"].describe()

# Exibir as tabelas

tma_por_produto
csat_por_produto

# Criando boxplots para visualizar a variação do TMA por Produto
plt.figure(figsize=(10, 6))
sns.boxplot(x=df["produto"], y=df["TMA"], palette="Blues")
plt.title("Distribuição do TMA por Produto")
plt.xlabel("Produto")
plt.ylabel("Tempo Médio de Atendimento (minutos)")
plt.xticks(rotation=45)
plt.show()

# Criando boxplots para visualizar a variação da Nota CSAT por Produto
plt.figure(figsize=(10, 6))
sns.boxplot(x=df["produto"], y=df["nota_csat"], palette="Greens")
plt.title("Distribuição da Nota CSAT por Produto")
plt.xlabel("Produto")
plt.ylabel("Nota CSAT")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Os gráficos apresentam a variação do Tempo Médio de Atendimento (TMA) e da Nota CSAT por produto/serviço.
#
# Essa análise permite avaliar a eficiência operacional e a satisfação do cliente para cada tipo de atendimento.
#
# **1. Análise do TMA por Produto**
#
# - A distribuição do TMA varia entre os produtos, sendo que alguns apresentam maior variabilidade, sugerindo casos de complexidade distinta.
#
# - Produtos com medianas mais elevadas indicam que, em média, o tempo de atendimento tende a ser mais longo para esses casos.
#
# **2. Análise da Nota CSAT por Produto**
#
# - Alguns produtos apresentam avaliações consistentemente mais baixas, sugerindo insatisfação com o suporte ou problemas na qualidade do serviço oferecido.
#
# - A alta dispersão em algumas categorias pode indicar inconsistência no atendimento, com clientes extremamente satisfeitos e outros muito insatisfeitos.
#
# - Produtos com CSAT mais alto e TMA elevado podem sugerir que os clientes valorizam mais a qualidade da resolução do que a rapidez do atendimento.
#
# **Interpretação Geral:**
#
# - Revisar processos de suporte para produtos com TMA elevado e avaliar possíveis otimizações.
#
# - Investigar os produtos com CSAT baixo para identificar pontos de insatisfação e corrigi-los.
#
# - Melhorar a padronização no atendimento para reduzir a dispersão de notas e garantir maior consistência na experiência do cliente.
#
# Com essas estratégias, a empresa pode melhorar a eficiência operacional e garantir uma experiência mais positiva para os clientes, independentemente do produto ou serviço atendido.

# %% [markdown]
# ### f) Análise de TMA e CSAT por turno

# %%
# Estatísticas descritivas do TMA e Nota CSAT por turno
tma_por_turno = df.groupby("turno")["TMA"].describe()
csat_por_turno = df.groupby("turno")["nota_csat"].describe()

# Criando boxplots para visualizar a variação do TMA por Turno
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["turno"], y=df["TMA"], palette="coolwarm")
plt.title("Distribuição do TMA por Turno")
plt.xlabel("Turno")
plt.ylabel("Tempo Médio de Atendimento (minutos)")
plt.show()

# Criando boxplots para visualizar a variação da Nota CSAT por Turno
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["turno"], y=df["nota_csat"], palette="viridis")
plt.title("Distribuição da Nota CSAT por Turno")
plt.xlabel("Turno")
plt.ylabel("Nota CSAT")
plt.show()

# %% [markdown]
# Os gráficos apresentam a variação do Tempo Médio de Atendimento (TMA) e da Nota CSAT por turno de atendimento (manhã, tarde e noite).
#
# Essa análise permite avaliar a eficiência operacional e a satisfação do cliente em diferentes períodos do dia.
#
# **1. TMA por Turno**
#
# - O turno da noite apresenta um TMA significativamente mais alto em comparação com os turnos da manhã e tarde.
#
# - Isso pode indicar sobrecarga de atendimentos no período noturno ou menor eficiência da equipe nesse horário.
#
# - Os turnos da manhã e tarde possuem distribuições de TMA similares, sugerindo uma divisão equilibrada de carga de trabalho nesses períodos.
#
# **2. Nota CSAT por Turno**
#
# - A nota CSAT tem distribuição semelhante entre os três turnos, sugerindo que a satisfação do cliente não varia drasticamente com o horário do atendimento.
#
# - Se um turno apresentasse CSAT significativamente menor, isso poderia indicar atrasos, baixa qualidade no suporte ou menor disponibilidade da equipe.
#
# - A dispersão da Nota CSAT pode indicar variação na qualidade do atendimento dentro do mesmo turno, sugerindo a necessidade de padronização nos processos.
#
# - Caso a nota CSAT seja alta mesmo no turno com TMA elevado (noite), isso sugere que os clientes valorizam mais a resolução do problema do que a rapidez do atendimento.
#
# **Ações Sugeridas**
#
# - Reforçar a equipe no turno noturno para reduzir o TMA e equilibrar a carga de trabalho.
#
# - Acompanhar a evolução do CSAT para identificar possíveis quedas na satisfação ao longo dos turnos.
#
# - Treinar a equipe para manter um padrão de qualidade independentemente do horário do atendimento.
#
# Com essas estratégias, é possível otimizar a eficiência do suporte e garantir uma experiência mais satisfatória para os clientes em todos os turnos.

# %% [markdown]
# ### g) Verificando se determinados atendentes impactam os resultados dentro de cada turno e produto.

# %%
# Estatísticas descritivas do TMA e Nota CSAT por Atendente
tma_por_atendente = df.groupby("atendente_nome")["TMA"].describe()
csat_por_atendente = df.groupby("atendente_nome")["nota_csat"].describe()

# Criando boxplots para visualizar a variação do TMA por Atendente
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["atendente_nome"], y=df["TMA"], palette="coolwarm")
plt.title("Distribuição do TMA por Atendente")
plt.xlabel("Atendente")
plt.ylabel("Tempo Médio de Atendimento (minutos)")
plt.xticks(rotation=45)
plt.show()

# Criando boxplots para visualizar a variação da Nota CSAT por Atendente
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["atendente_nome"], y=df["nota_csat"], palette="viridis")
plt.title("Distribuição da Nota CSAT por Atendente")
plt.xlabel("Atendente")
plt.ylabel("Nota CSAT")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Os gráficos apresentam a distribuição do Tempo Médio de Atendimento (TMA) e da Nota CSAT por atendente, permitindo avaliar a eficiência e a qualidade do suporte prestado.
#
# **1. TMA por Atendente**
#
# - A mediana do TMA é relativamente próxima entre os atendentes, sugerindo um padrão consistente de tempo de atendimento na equipe.
#
# - Alguns atendentes apresentam maior dispersão no TMA, o que pode indicar que eles lidam com chamados de complexidade variável.
#
# - Atendentes com TMA consistentemente alto podem estar enfrentando dificuldades para resolver problemas rapidamente.
#
# - Atendentes com TMA muito baixo podem estar atendendo de forma rápida, mas isso pode afetar a qualidade do suporte prestado.
#
# - A presença de outliers pode indicar chamados mais longos e complexos ou dificuldades operacionais.
#
# **2. Nota CSAT por Atendente**
#
# - Alguns atendentes apresentam notas CSAT consistentemente baixas, o que pode indicar necessidade de treinamento ou falhas na comunicação com os clientes.
#
# - Outros atendentes conseguem manter notas CSAT altas mesmo com TMA elevado, sugerindo que a qualidade do atendimento é valorizada pelos clientes, mesmo que o tempo seja maior.
#
# - Se houver grande variação na nota CSAT dentro de um mesmo atendente, pode ser necessário padronizar os procedimentos para garantir consistência na experiência do cliente.
#
# **Ações Sugeridas**
#
# - Criar um plano de desenvolvimento para atendentes com baixo CSAT, focando em melhoria da comunicação e qualidade da resolução.
#
# - Revisar processos operacionais para otimizar o tempo de atendimento sem comprometer a qualidade.
#
# - Analisar atendentes com alta variabilidade no desempenho para identificar fatores que impactam a consistência do atendimento.
#
# Essas estratégias podem ajudar a melhorar a eficiência do suporte técnico e garantir uma experiência mais satisfatória para os clientes.

# %% [markdown]
# ### h) Verificando se atendimentos convertidos têm maior satisfação do cliente

# %%
# Estatísticas descritivas do TMA e Nota CSAT por conversão do atendimento
tma_por_conversao = df.groupby("conversao_atendimento")["TMA"].describe()
csat_por_conversao = df.groupby("conversao_atendimento")["nota_csat"].describe()

# Criando boxplots para visualizar a variação do TMA por Conversão de Atendimento
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["conversao_atendimento"], y=df["TMA"], palette="coolwarm")
plt.title("Distribuição do TMA por Conversão de Atendimento")
plt.xlabel("Conversão do Atendimento")
plt.ylabel("Tempo Médio de Atendimento (minutos)")
plt.show()

# Criando boxplots para visualizar a variação da Nota CSAT por Conversão de Atendimento
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["conversao_atendimento"], y=df["nota_csat"], palette="viridis")
plt.title("Distribuição da Nota CSAT por Conversão de Atendimento")
plt.xlabel("Conversão do Atendimento")
plt.ylabel("Nota CSAT")
plt.show()

# %% [markdown]
# Os gráficos e estatísticas mostram como a conversão do atendimento impacta o Tempo Médio de Atendimento (TMA) e a Nota CSAT.
#
# **Aqui estão os principais insights:**
#
# - O TMA não tem um impacto significativo na conversão do atendimento, já que os tempos médios são similares entre os grupos.
#
# - A conversão influencia positivamente a satisfação do cliente, já que clientes que tiveram seus chamados resolvidos tendem a dar notas CSAT mais altas.
#
# - A nota CSAT para atendimentos não convertidos é mais variável, o que pode indicar diferentes motivos de insatisfação (tempo de espera, falta de resolução ou atendimento inadequado).
#
# Com base nesses insights, a empresa pode considerar focar em estratégias para melhorar a conversão, garantindo que mais clientes tenham seus chamados resolvidos, o que consequentemente deve aumentar a satisfação geral.

# %% [markdown]
# ### i) Relação entre ticket reaberto e satisfação

# %%
# Estatísticas descritivas da Nota CSAT por status de reabertura do ticket
csat_por_reabertura = df.groupby("ticket_reaberto")["nota_csat"].describe()

# Criando boxplots para visualizar a relação entre Reabertura do Ticket e Nota CSAT
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["ticket_reaberto"], y=df["nota_csat"], palette="magma")
plt.title("Distribuição da Nota CSAT por Reabertura de Ticket")
plt.xlabel("Ticket Reaberto")
plt.ylabel("Nota CSAT")
plt.show()

# Criando um gráfico de barras para visualizar a frequência de reaberturas
plt.figure(figsize=(6, 4))
sns.countplot(x=df["ticket_reaberto"], palette="coolwarm")
plt.title("Frequência de Tickets Reabertos")
plt.xlabel("Ticket Reaberto")
plt.ylabel("Quantidade de Atendimentos")
plt.show()

# %% [markdown]
# Os gráficos demonstram a relação entre reabertura de tickets e a satisfação do cliente (CSAT), permitindo avaliar como a necessidade de um novo atendimento impacta a experiência do usuário.
#
# **1. Nota CSAT por Reabertura de Ticket**
#
# O boxplot compara a distribuição da nota CSAT entre atendimentos que tiveram seus tickets reabertos e aqueles que foram resolvidos na primeira interação.
#
# - A mediana da nota CSAT para tickets reabertos é ligeiramente menor do que a dos não reabertos, indicando que clientes que precisaram retornar para um novo atendimento ficaram, em média, menos satisfeitos.
#
# - A distribuição das notas em ambos os casos apresenta alta variabilidade, com clientes avaliando bem e mal em diferentes situações, sugerindo que a reabertura não é o único fator que influencia a satisfação.
#
# - O fato de as notas máximas serem semelhantes entre os dois grupos indica que, em alguns casos, mesmo tickets reabertos podem resultar em uma boa experiência, dependendo da resolução final do problema.
#
# **2. Frequência de Tickets Reabertos**
#
# O segundo gráfico mostra a quantidade de atendimentos que tiveram ou não tickets reabertos.
#
# - A maioria dos atendimentos não precisa ser reaberta, o que sugere que, na maior parte dos casos, a solução é entregue no primeiro contato.
#
# - Ainda assim, um número considerável de tickets é reaberto, indicando que uma parcela relevante dos atendimentos poderia ser aprimorada para evitar a necessidade de novas interações.
#
# **Ações Sugeridas**
#
# - Analisar os motivos mais frequentes para a reabertura de tickets e buscar melhorias nos processos internos.
#
# - Aprimorar a capacitação da equipe para aumentar a taxa de resolução na primeira interação.
#
# - Acompanhar as taxas de reabertura ao longo do tempo para avaliar a eficácia das mudanças implementadas.
#
# Com essas estratégias, a empresa pode aumentar a satisfação do cliente e reduzir a carga operacional do suporte.

# %% [markdown]
# ### j) Análise Temporal

# %%
# Criando colunas para análise temporal
df["data_atendimento"] = df["inicio_atendimento"].dt.date  # Apenas a data
df["mes_ano"] = df["inicio_atendimento"].dt.to_period("M")  # Mês/Ano

# Contagem de atendimentos por dia
atendimentos_por_dia = df.groupby("data_atendimento")["ticket_id"].count().reset_index()
atendimentos_por_dia.columns = ["Data", "Quantidade de Atendimentos"]

# Criando gráfico de atendimentos por dia
plt.figure(figsize=(12, 5))
plt.plot(atendimentos_por_dia["Data"], atendimentos_por_dia["Quantidade de Atendimentos"], marker='o', linestyle='-')
plt.title("Atendimentos por Dia")
plt.xlabel("Data")
plt.ylabel("Quantidade de Atendimentos")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# Os gráficos apresentam a variação da quantidade de atendimentos por dia e mês, permitindo identificar tendências temporais e possíveis sazonalidades na demanda.
#
# **Aqui estão algumas possíveis observações:**
#
# - No dia 1º de dezembro, o volume de atendimentos foi relativamente baixo, seguido por um aumento expressivo no dia 2 de dezembro, atingindo um pico acima de 450 atendimentos.
#
# - Nos dias seguintes, o número de atendimentos manteve-se em um patamar elevado, com pequenas variações.
#
# - No dia 8 de dezembro, há uma queda acentuada no volume de atendimentos, possivelmente indicando um evento específico (como feriado, mudanças no fluxo de chamados ou falhas no sistema de suporte).
#
# **Ações sugeridas:**
#
# - Verificar possíveis eventos externos que possam ter causado a queda brusca no dia 8.
#
# - Monitorar padrões semelhantes em outros períodos para antecipar oscilações e alocar recursos de forma eficiente.
#
# - Avaliar se o pico no dia 2 foi impulsionado por um aumento pontual na demanda ou se reflete um padrão recorrente.
#
# **Conclusão**
#
# - A distribuição de atendimentos por dia apresenta picos e quedas significativas, exigindo um monitoramento mais detalhado para evitar sobrecargas ou ociosidade da equipe.
#
# - O número total de atendimentos mensais reflete um alto volume de chamados, reforçando a necessidade de um planejamento adequado de recursos.
#
# - Otimizar a alocação da equipe com base nos padrões diários pode reduzir tempos de espera e melhorar a satisfação dos clientes.
#
# Com essas análises, a empresa pode ajustar estratégias de atendimento, garantindo um suporte técnico mais eficiente e alinhado às necessidades dos clientes

# %% [markdown]
# ### k) Análise de Picos de Atendimento ao Longo do Dia

# %%
# Criando uma coluna com a hora do início do atendimento
df["hora_atendimento"] = df["inicio_atendimento"].dt.hour

# Contagem de atendimentos por horário
atendimentos_por_hora = df.groupby("hora_atendimento")["ticket_id"].count().reset_index()
atendimentos_por_hora.columns = ["Hora do Dia", "Quantidade de Atendimentos"]

# Criando gráfico de atendimentos por horário
plt.figure(figsize=(10, 5))
plt.bar(atendimentos_por_hora["Hora do Dia"], atendimentos_por_hora["Quantidade de Atendimentos"], color='orange')
plt.title("Atendimentos por Hora do Dia")
plt.xlabel("Hora do Dia")
plt.ylabel("Quantidade de Atendimentos")
plt.xticks(range(0, 24))
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# O gráfico mostra a distribuição dos atendimentos ao longo do dia.
#
# **Aqui estão algumas possíveis interpretações:**
#
# **1. Horários de Maior Demanda**
#
# - Observa-se um pico de atendimentos entre 2h e 3h da manhã, indicando um período de alta demanda inesperada para esse horário.
#
# - Outro pico significativo ocorre por volta das 20h e 21h, sugerindo que muitos clientes buscam suporte no período noturno.
#
# - Esses horários podem exigir reforço da equipe para evitar sobrecarga e longos tempos de espera.
#
# **2. Horários de Menor Demanda**
#
# - Entre 17h e 18h, há uma leve queda na quantidade de atendimentos, sugerindo um período de transição no fluxo de chamados.
#
# - Após as 23h, observa-se uma redução no volume de atendimentos, o que pode indicar um período adequado para reduzir a equipe.
#
# **3. Possíveis Causas dos Picos**
#
# - Pico no início do expediente (madrugada): Pode indicar que problemas se acumulam antes da abertura oficial do suporte, levando a um aumento na demanda quando o serviço se torna disponível.
#
# - Pico no final do dia (20h - 21h): Sugere que muitos clientes deixam para buscar suporte no fim do expediente, podendo indicar atrasos na solução de problemas ou dificuldades no atendimento durante o dia.
#
# **Conclusão e Ações Sugeridas**
#
# - Reforçar a equipe nos horários de pico para evitar tempos de espera elevados e garantir um atendimento mais eficiente.
#
# - Reduzir a equipe nos períodos de baixa demanda para otimizar custos operacionais.
#
# - Investigar o motivo da alta demanda na madrugada, verificando se há um acúmulo de chamados de períodos anteriores.
#
# - Melhorar a eficiência do suporte durante o dia, garantindo que menos chamados fiquem pendentes para o final do expediente.
#
# Essa análise permite otimizar a distribuição da equipe e melhorar a experiência do cliente, garantindo que o suporte seja oferecido de forma eficiente ao longo do dia.

# %% [markdown]
# ### l) Evolução da Satisfação do Cliente (CSAT)

# %%
# Média da Nota CSAT por dia
csat_por_dia = df.groupby("data_atendimento")["nota_csat"].mean().reset_index()
csat_por_dia.columns = ["Data", "Média Nota CSAT"]

# Criando gráfico da evolução da Nota CSAT por Dia
plt.figure(figsize=(12, 5))
plt.plot(csat_por_dia["Data"], csat_por_dia["Média Nota CSAT"], marker='o', linestyle='-', color='green')
plt.title("Evolução da Nota CSAT por Dia")
plt.xlabel("Data")
plt.ylabel("Média da Nota CSAT")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# O gráfico apresenta a evolução da média da Nota CSAT por dia, permitindo identificar tendências e padrões na satisfação do cliente ao longo do tempo.
#
# A linha mostra variações na média da Nota CSAT ao longo dos dias analisados.
#
# - Houve uma queda acentuada na Nota CSAT no dia 04/12, o que pode indicar problemas operacionais, falhas técnicas ou insatisfação generalizada com o suporte.
#
# - Nos dias seguintes, a nota se recupera gradualmente, sugerindo que a situação pode ter sido normalizada ou que ações corretivas foram tomadas.
#
# - No dia 08/12, a nota atinge seu maior pico, sugerindo uma melhora significativa na experiência do cliente.
#
# - Se essa oscilação for frequente, pode indicar inconsistências no atendimento, possivelmente devido a diferenças no desempenho da equipe ou na complexidade dos chamados.
#
# **Ações Sugeridas**
#
# - Analisar os motivos da queda na nota CSAT no dia 04/12 para evitar recorrências.
#
# - Avaliar as estratégias que contribuíram para a recuperação e reforçá-las na operação.
#
# - Monitorar continuamente a evolução da CSAT para garantir a consistência na qualidade do atendimento.
#
# Com essas iniciativas, a empresa pode fortalecer a experiência do cliente, garantindo um suporte técnico mais estável e satisfatório ao longo do tempo.

# %% [markdown]
# ## Recomendações e Ações Sugeridas

# %% [markdown]
# **Com base nas descobertas, recomendamos:**
#
# - Treinamento para atendentes com baixo desempenho: Melhorar habilidades de resolução de problemas e comunicação para garantir um atendimento mais eficaz.
#
# - Revisão dos processos para produtos com maior tempo de atendimento: Identificar possíveis otimizações para reduzir o tempo médio de suporte e melhorar a experiência do cliente.
#
# - Monitoramento da taxa de reabertura de tickets: Criar um plano de ação para minimizar a necessidade de atendimentos recorrentes.
#
# - Ajuste da escala de trabalho com base na demanda: Reforçar a equipe nos horários de pico para evitar sobrecarga e melhorar a eficiência do suporte.
#
# - Análise contínua dos padrões de satisfação: Monitorar a evolução das métricas para garantir que as ações implementadas gerem impacto positivo.

# %% [markdown]
# ## Conclusão: O Caminho para a Transformação do Suporte ao Cliente
#
# A análise revelou padrões significativos no desempenho do suporte técnico, permitindo a identificação de oportunidades estratégicas para aprimorar o atendimento e aumentar a satisfação dos clientes.
#
# Os resultados mostram que, apesar de um desempenho geral positivo, há oportunidades claras para otimizar a eficiência do suporte e melhorar a experiência do cliente. O próximo passo é a implementação das recomendações sugeridas, com monitoramento contínuo dos indicadores de desempenho, garantindo uma evolução progressiva nos processos de suporte.
#
# A empresa, com essa análise detalhada, conseguiu identificar os principais pontos de melhoria no atendimento ao cliente, possibilitando a implementação de ações direcionadas, tais como:
#
# - Redesenho das escalas para balancear melhor os períodos de pico.
#
# - Treinamento personalizado para atendentes com baixa conversão.
#
# - Revisão dos processos internos para reduzir tempos de atendimento sem comprometer a qualidade.
#
# Com essas iniciativas, a empresa conseguiu fortalecer seu suporte técnico, proporcionando um atendimento mais eficiente, ágil e satisfatório para seus clientes.
